# %%
import urllib.request
import json
import numpy as np

# %% [markdown]
# # load data as runInfo

# %%
data_urls = [
    'https://raw.githubusercontent.com/KU81-ComSci-ProjectEnd-GameCard/main/master/raw_data/2020-11-01-00-07%231067.json',
    'https://raw.githubusercontent.com/KU81-ComSci-ProjectEnd-GameCard/main/master/raw_data/2020-11-01-00-17%231152.json',
    'https://raw.githubusercontent.com/KU81-ComSci-ProjectEnd-GameCard/main/master/raw_data/2020-11-01-00-27%231120.json',
    'https://raw.githubusercontent.com/KU81-ComSci-ProjectEnd-GameCard/main/master/raw_data/2020-11-01-00-37%231158.json'
  ]

json_data = list()
for data_url in data_urls:
  print(f'Loading {data_url}')
  with urllib.request.urlopen(data_url) as url:
    json_data.extend(json.loads(url.read().decode()))
# Out:
# Loading https://raw.githubusercontent.com/KU81-ComSci-ProjectEnd-GameCard/main/master/raw_data/2020-11-01-00-07%231067.json
# Loading https://raw.githubusercontent.com/KU81-ComSci-ProjectEnd-GameCard/main/master/raw_data/2020-11-01-00-17%231152.json
# Loading https://raw.githubusercontent.com/KU81-ComSci-ProjectEnd-GameCard/main/master/raw_data/2020-11-01-00-27%231120.json
# Loading https://raw.githubusercontent.com/KU81-ComSci-ProjectEnd-GameCard/main/master/raw_data/2020-11-01-00-37%231158.json

# %%
import pandas as pd
df = pd.DataFrame(json_data)

# %%
runInfo = df['event'].apply(pd.Series)

# %% [markdown]
# # ALL card
# but only ironclad , colorless , curse

# %%
IC_ATTACK_CARDS = ["Strike_R", "Bash", "Anger", "Body Slam", "Clash", "Cleave", "Clothesline", "Headbutt", "Heavy Blade", "Iron Wave", "Perfected Strike", "Pommel Strike", "Sword Boomerang", "Thunderclap", "Twin Strike", "Wild Strike", "Blood for Blood", "Carnage", "Dropkick", "Hemokinesis", "Pummel", "Rampage", "Reckless Charge", "Searing Blow", "Sever Soul", "Uppercut", "Whirlwind", "Bludgeon", "Feed", "Fiend Fire", "Immolate", "Reaper"]
IC_SKILL_CARDS = ["Defend_R", "Armaments", "Flex", "Havoc", "Shrug It Off", "True Grit", "Warcry", "Battle Trance", "Bloodletting", "Burning Pact", "Disarm", "Dual Wield", "Entrench", "Flame Barrier", "Ghostly Armor", "Infernal Blade", "Intimidate", "Power Through", "Rage", "Second Wind", "Seeing Red", "Sentinel", "Shockwave", "Spot Weakness", "Double Tap", "Exhume", "Impervious", "Limit Break", "Offering"]
IC_POWER_CARDS = ["Combust", "Dark Embrace", "Evolve", "Feel No Pain", "Fire Breathing", "Inflame", "Metallicize", "Rupture", "Barricade", "Berserk", "Brutality", "Corruption", "Demon Form", "Juggernaut"]
IRONCLAD_CARDS = IC_ATTACK_CARDS + IC_SKILL_CARDS + IC_POWER_CARDS

COLORLESS_CARDS = ["Dramatic Entrance", "Flash of Steel", "Mind Blast", "Swift Strike", "HandOfGreed", "Bite", "Expunger", "Ritual Dagger", "Shiv", "Smite", "Through Violence", "Bandage Up", "Blind", "Dark Shackles", "Deep Breath", "Discovery", "Enlightenment", "Finesse", "Forethought", "Good Instincts", "Impatience", "Jack Of All Trades", "Madness", "Panacea", "PanicButton", "Purity", "Trip", "Apotheosis", "Chrysalis", "Master of Strategy", "Metamorphosis", "Secret Technique", "Secret Weapon", "The Bomb", "Thinking Ahead", "Transmutation", "Violence", "Apparition", "Beta", "Insight", "J.A.X.", "Miracle", "Safety", "Magnetism", "Mayhem", "Panache", "Sadistic Nature", "Omega", ]

CURSE_CARDS = ["Ascender s Bane", "Clumsy", "Curse of the Bell", "Decay", "Doubt", "Injury", "Necronomicurse", "Normality", "Pain", "Parasite", "Pride", "Regret", "Shame", "Writhe"]

# %%
def upgrade_lst(lst):
  new_lst = list()
  for item in lst:
    if(item == 'Searing Blow'):
      new_lst.append('Searing Blow')
    else:
      new_lst.append(item+'+1')
  return new_lst

# %%
ALL_CARD = IRONCLAD_CARDS + COLORLESS_CARDS + CURSE_CARDS + upgrade_lst(IRONCLAD_CARDS) + upgrade_lst(COLORLESS_CARDS)

# %% [markdown]
# # Filtering runInfo

# %% [markdown]
# speciel case for 'Searing Blow' that can upgrade many time

# %%
import re
def clear_SearingBlowPlus(lst):
    return [re.sub(r'Searing Blow\+\d+', 'Searing Blow', item) for item in lst]
runInfo['master_deck'] = runInfo['master_deck'].apply(clear_SearingBlowPlus)

# %%
def is_subset(words, lst):
    return all(word in lst for word in words)
filtered_df = runInfo[runInfo['master_deck'].apply(lambda x: is_subset(x, ALL_CARD))]

# %%
filtered_df
# Out:
#                                          gold_per_floor  floor_reached  \
# 0                                              [99, 99]              0
# 9     [110, 125, 300, 300, 101, 135, 85, 100, 180, 2...             22
# 26        [117, 129, 129, 54, 4, 4, 38, 38, 38, 38, 38]             10
# 44    [109, 109, 109, 109, 124, 155, 155, 180, 180, ...             56
# 49    [367, 379, 389, 24, 39, 70, 70, 103, 103, 103,...             16
# ...                                                 ...            ...
# 4591  [111, 122, 122, 122, 122, 122, 157, 157, 157, ...             56
# 4597  [114, 134, 146, 166, 177, 177, 142, 152, 152, ...             27
# 4608  [114, 114, 128, 146, 158, 158, 191, 191, 268, ...             23
# 4619  [14, 29, 40, 40, 58, 58, 140, 140, 166, 177, 1...             23
# 4626  [119, 132, 148, 148, 165, 195, 210, 237, 263, ...             24
#
#       playtime                  items_purged  score  \
# 0            9                            []      0
# 9          553                       [Doubt]    242
# 26          73                    [Defend_R]    129
# 44        9434         [Strike_R, Normality]   1425
# 49        1072                            []    118
# ...        ...                           ...    ...
# 4591      2981  [Strike_R, Clash+1, Inflame]   1377
# 4597      1062                            []    248
# 4608      1438          [Defend_R, Strike_R]    222
# 4619      1200                            []    237
# 4626      1827                    [Strike_R]    344
#
#                                    play_id      local_time  is_ascension_mode  \
# 0     3b384338-f024-4768-9f18-1be22575dd74  20201101092739               True
# 9     70de6eff-2a0c-4f4f-8541-393aad5df8d9  20201101012742              False
# 26    5cd12877-da35-4be8-852f-4097c49f4538  20201101082755               True
# 44    1d3f6bb0-2486-4ca5-be1b-002c35e12869  20201101002807               True
# 49    65cfc4f4-8d61-451c-9317-5371397d65d9  20201031202807              False
# ...                                    ...             ...                ...
# 4591  b25f5c2e-9cf2-4890-91af-8d58df6b7489  20201031173719              False
# 4597  acd99ae8-89d8-486d-8d09-d750b30af143  20201101083722               True
# 4608  5edb42a7-e7cd-44dd-89d1-f0f62f9f934c  20201031193730               True
# 4619  07cb803a-3860-457f-b34b-f5115c820bca  20201031203738              False
# 4626  affff8a8-52ed-45c6-af9b-68d35f72898b  20201031193740               True
#
#                                        campfire_choices            neow_cost  \
# 0                                                    []                 NONE
# 9     [{'data': 'Barricade', 'floor': 13, 'key': 'SM...                 NONE
# 26                      [{'floor': 6, 'key': 'RECALL'}]                 NONE
# 44    [{'data': 'True Grit', 'floor': 15.0, 'key': '...                 NONE
# 49    [{'floor': 7, 'key': 'REST'}, {'data': 'Reaper...       PERCENT_DAMAGE
# ...                                                 ...                  ...
# 4591  [{'data': 'Inflame', 'floor': 6.0, 'key': 'SMI...                 NONE
# 4597  [{'data': 'Seeing Red', 'floor': 6, 'key': 'SM...                 NONE
# 4608  [{'floor': 6, 'key': 'RECALL'}, {'data': 'Sear...  TEN_PERCENT_HP_LOSS
# 4619  [{'data': 'Clash', 'floor': 6, 'key': 'SMITH'}...              NO_GOLD
# 4626  [{'data': 'Iron Wave', 'floor': 13, 'key': 'SM...                 NONE
#
#       ...                                    relics_obtained  \
# 0     ...                                                 []
# 9     ...  [{'floor': 4, 'key': 'Regal Pillow'}, {'floor'...
# 26    ...  [{'floor': 7, 'key': 'Vajra'}, {'floor': 9, 'k...
# 44    ...  [{'floor': 6.0, 'key': 'HornCleat'}, {'floor':...
# 49    ...  [{'floor': 6, 'key': 'Incense Burner'}, {'floo...
# ...   ...                                                ...
# 4591  ...  [{'floor': 7.0, 'key': 'Red Skull'}, {'floor':...
# 4597  ...  [{'floor': 9, 'key': 'Molten Egg 2'}, {'floor'...
# 4608  ...  [{'floor': 7, 'key': 'Champion Belt'}, {'floor...
# 4619  ...  [{'floor': 7, 'key': 'Bottled Tornado'}, {'flo...
# 4626  ...  [{'floor': 6, 'key': 'Bag of Preparation'}, {'...
#
#                                           event_choices is_beta  \
# 0                                                    []   False
# 9     [{'damage_healed': 0, 'gold_gain': 175, 'playe...   False
# 26    [{'damage_healed': 0, 'gold_gain': 0, 'player_...   False
# 44    [{'damage_healed': 0.0, 'max_hp_gain': 0.0, 'm...   False
# 49    [{'damage_healed': 26, 'gold_gain': 0, 'player...   False
# ...                                                 ...     ...
# 4591  [{'damage_healed': 0.0, 'max_hp_gain': 0.0, 'm...   False
# 4597  [{'damage_healed': 20, 'gold_gain': 0, 'player...   False
# 4608  [{'damage_healed': 0, 'gold_gain': 0, 'player_...   False
# 4619  [{'damage_healed': 0, 'gold_gain': 0, 'player_...   False
# 4626  [{'cards_removed': ['Strike_R'], 'damage_heale...   False
#
#                                             boss_relics items_purged_floors  \
# 0                                                    []                  []
# 9     [{'not_picked': ['Runic Pyramid', 'Fusion Hamm...                 [5]
# 26                                                   []                 [4]
# 44    [{'not_picked': ['Tiny House', 'SlaversCollar'...            [13, 53]
# 49                                                   []                  []
# ...                                                 ...                 ...
# 4591  [{'not_picked': ['Black Star', 'Black Blood'],...        [13, 37, 53]
# 4597  [{'not_picked': ['Velvet Choker', 'Tiny House'...                  []
# 4608  [{'not_picked': ['Philosopher's Stone', 'Mark ...            [13, 19]
# 4619  [{'not_picked': ['Mark of Pain', 'Black Star']...                  []
# 4626  [{'not_picked': ['Runic Cube', 'Snecko Eye'], ...                [10]
#
#      is_endless                              potions_floor_spawned  \
# 0         False                                                 []
# 9         False                                     [1, 6, 16, 21]
# 26        False                                             [2, 7]
# 44        False         [1, 8, 12, 16, 24, 27, 30, 36, 38, 45, 46]
# 49        False                                      [2, 3, 5, 12]
# ...         ...                                                ...
# 4591      False  [1, 14, 16, 18, 24, 25, 30, 33, 35, 38, 39, 40...
# 4597      False                           [1, 4, 5, 8, 10, 18, 24]
# 4608      False                                  [1, 5, 7, 12, 21]
# 4619      False                                 [1, 5, 12, 14, 16]
# 4626      False                           [1, 3, 5, 6, 16, 20, 23]
#
#      ascension_level                   killed_by special_seed
# 0                  2                         NaN          NaN
# 9                  0  Shelled Parasite and Fungi          NaN
# 26                 9                   Lagavulin          NaN
# 44                 6                         NaN          0.0
# 49                 0                   Hexaghost          NaN
# ...              ...                         ...          ...
# 4591               0                         NaN          0.0
# 4597               2                     Slavers          NaN
# 4608               3                     Slavers          NaN
# 4619               0                     Slavers          NaN
# 4626               7        Centurion and Healer          NaN
#
# [896 rows x 50 columns]
