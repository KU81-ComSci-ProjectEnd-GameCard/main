# %%
from tensorflow.keras.models import load_model
from joblib import load
import numpy as np

# %%
def cosine_similarity(vector1, vector2):
    dot_product = np.dot(vector1, vector2)
    norm1 = np.linalg.norm(vector1)
    norm2 = np.linalg.norm(vector2)
    if norm1 == 0 or norm2 == 0:
        return np.array(0.0)
    similarity = dot_product / (norm1 * norm2)
    return similarity

# %%
model = load_model('trained_model/MIX_11k_20dim_V1.keras', compile=False)

# %%
def custom_analyzer(doc):
    return doc
cardVec = load('matrix_data/cardVecTF_MIX_11k_20dim.joblib')
deckVecorizer = load('matrix_data/deckVectorizer_MIX_11k_30K.joblib')

# %%
ic_smaple = list([ ["Strike_R"] * 5 + ["Defend_R"]*5 +   ["Bash"] +['Anger'] ])

# %%
sampleVec = deckVecorizer.transform(ic_smaple).toarray()

# %%
sample_pred = model.predict(sampleVec)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step

# %%
sample_pred.shape
# Out:
# (1, 20)

# %%
sample_sim= list()
for card, vector in cardVec.items():
    sample_sim.append( (card,cosine_similarity(sample_pred, vector)) )

# %%
sample_sim ## it show score of all card
# Out:
# [('Strike_R', array([0.00779985])),
#  ('Bash', array([0.87259256])),
#  ('Anger', array([0.673943])),
#  ('Body Slam', array([0.7173273])),
#  ('Clash', array([0.50067427])),
#  ('Cleave', array([0.79728015])),
#  ('Clothesline', array([0.92301217])),
#  ('Headbutt', array([0.97173206])),
#  ('Heavy Blade', array([0.76737556])),
#  ('Iron Wave', array([0.73303061])),
#  ('Perfected Strike', array([0.56475794])),
#  ('Pommel Strike', array([0.75724059])),
#  ('Sword Boomerang', array([0.82086666])),
#  ('Thunderclap', array([0.80479941])),
#  ('Twin Strike', array([0.54545614])),
#  ('Wild Strike', array([0.38061339])),
#  ('Blood for Blood', array([0.82080775])),
#  ('Carnage', array([0.93308953])),
#  ('Dropkick', array([0.90277448])),
#  ('Hemokinesis', array([0.84564398])),
#  ('Pummel', array([0.74549614])),
#  ('Rampage', array([0.8031608])),
#  ('Reckless Charge', array([0.76806707])),
#  ('Searing Blow', array([0.62906074])),
#  ('Sever Soul', array([0.94608958])),
# ...
